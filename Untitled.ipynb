# %%
import pandas as pd

# %%
pd.read_pickle('/home/anamikas/work/igacat_server/deepGO_component/src/resources/bp.pkl')
# Out:
#       functions
# 0    GO:0007626
# 1    GO:0007611
# 2    GO:0044708
# 3    GO:0007610
# 4    GO:0007268
# 5    GO:0098916
# 6    GO:0099537
# 7    GO:0099536
# 8    GO:0007267
# 9    GO:0044700
# 10   GO:0023052
# 11   GO:0044085
# 12   GO:0030031
# 13   GO:0010927
# 14   GO:0043623
# 15   GO:0051260
# 16   GO:0051259
# 17   GO:0006461
# 18   GO:0022618
# 19   GO:0034622
# 20   GO:0065003
# 21   GO:0070925
# 22   GO:0022607
# 23   GO:0048812
# 24   GO:0048858
# 25   GO:0030030
# 26   GO:0072657
# 27   GO:0044802
# 28   GO:0061024
# 29   GO:0071555
# ..          ...
# 902  GO:0006954
# 903  GO:0006952
# 904  GO:0006950
# 905  GO:0006959
# 906  GO:0006955
# 907  GO:1990267
# 908  GO:0009636
# 909  GO:0046686
# 910  GO:0010038
# 911  GO:0010035
# 912  GO:0070848
# 913  GO:0014070
# 914  GO:0034097
# 915  GO:0033993
# 916  GO:0009743
# 917  GO:0097305
# 918  GO:1901654
# 919  GO:0010033
# 920  GO:1901700
# 921  GO:1901698
# 922  GO:0042493
# 923  GO:0001101
# 924  GO:0042221
# ...

# %%
import csv

# %%
reader = csv.reader(open("/home/anamikas/work/results.txt"), delimiter='\t')

# %%
reader

# %%
for row in reader:
    print(row)
# Out:
# ['GO:0006811', '0.40467736']
# ['GO:0034220', '0.9212458']
# ['GO:0012501', '0.8748045']
# ['GO:0044265', '0.98103553']
# ['GO:0006511', '0.8504019']
# ['GO:0032446', '0.8425679']
# ['GO:0072522', '0.75941545']
# ['GO:1903047', '0.90120405']
# ['GO:0046686', '0.9568645']
# ['GO:0046486', '0.54303885']
# ['GO:1904951', '0.8242568']
# ['GO:0042326', '0.8242568']
# ['GO:0060255', '0.43569922']
# ['GO:1903829', '0.5078778']
# ['GO:0045017', '0.89097726']
# ['GO:0045321', '0.9568645']
# ['GO:0045927', '0.9837472']
# ['GO:0052548', '0.9907706']
# ['GO:0050900', '0.9713868']
# ['GO:0040011', '0.98101026']
# ['GO:0000226', '0.8470896']
# ['GO:0010608', '0.88291126']
# ['GO:0009117', '0.8644503']
# ['GO:0009058', '0.92700577']
# ['GO:0044703', '0.8145089']
# ['GO:0044270', '0.9619488']
# ['GO:0009617', '0.7087743']
# ['GO:0010646', '0.33566034']
# ['GO:0090150', '0.63367885']
# ['GO:1901700', '0.9442362']
# ['GO:0051052', '0.8139281']
# ['GO:0051129', '0.9568645']
# ...
